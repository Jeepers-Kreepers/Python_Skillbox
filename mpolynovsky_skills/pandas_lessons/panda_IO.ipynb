# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Star_Trek:_Deep_Space_Nine'
#url = 'https://technobee.ru/index.php/pilotazh/spravochnik-aviatekhnika/item/1-massa-i-ves'

# %%
# read in an HTML table
tables = pd.read_html(url)
#print(tables)
ds9_actors = tables[1]
ds9_actors
# Out:
#                Actor                                          Character  \
# 0       Avery Brooks                                     Benjamin Sisko
# 1       Avery Brooks  Benjamin Sisko is the Starfleet officer placed...
# 2   René Auberjonois                                                Odo
# 3   René Auberjonois  Constable Odo is the station's chief of securi...
# 4   Alexander Siddig                                      Julian Bashir
# 5   Alexander Siddig  Julian Bashir is the station's chief medical o...
# 6      Terry Farrell                                         Jadzia Dax
# 7      Terry Farrell  Jadzia Dax is the station's science officer. A...
# 8      Cirroc Lofton                                         Jake Sisko
# 9      Cirroc Lofton  Jake is Benjamin Sisko's son. He at first rese...
# 10       Colm Meaney                                      Miles O'Brien
# 11       Colm Meaney  Miles O'Brien is the Chief of Operations, resp...
# ...
